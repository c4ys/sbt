# %%
from xtquant import xtdata

# %%
xtdata.download_history_data('000001.SH','5m', '20240901', '20250801')

# %%
data = xtdata.get_market_data(field_list=[], stock_list=['000001.SH'], period='30m', start_time='20240901', end_time='20250801', count=-1,dividend_type='back_ratio')
data
# Out:
# {'time':            20240902100000  20240902103000  20240902110000  20240902113000  \
#  000001.SH   1725242400000   1725244200000   1725246000000   1725247800000
#
#             20240902133000  20240902140000  20240902143000  20240902150000  \
#  000001.SH   1725255000000   1725256800000   1725258600000   1725260400000
#
#             20240903100000  20240903103000  ...  20250731143000  \
#  000001.SH   1725328800000   1725330600000  ...   1753943400000
#
#             20250731150000  20250801100000  20250801103000  20250801110000  \
#  000001.SH   1753945200000   1754013600000   1754015400000   1754017200000
#
#             20250801113000  20250801133000  20250801140000  20250801143000  \
#  000001.SH   1754019000000   1754026200000   1754028000000   1754029800000
#
#             20250801150000
#  000001.SH   1754031600000
#
#  [1 rows x 1760 columns],
#  'open':            20240902100000  20240902103000  20240902110000  20240902113000  \
# ...
